# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from datetime import date
from datetime import timedelta

class Playlist:
    def __init__(self,URL):
        # The __init__ method is run everytime we create new instance
        # The following are called instance attributes
        self.URL = URL
        self.content = soup = BeautifulSoup(requests.get(URL).content, "html.parser")
    
    def day_clean(self,date_string):
        today = date.today()
        week_days = {"Monday": 0,
                    "Tuesday": 1,
                    "Wednesday": 2,
                    "Thursday": 3,
                    "Friday": 4,
                    "Saturday": 5,
                    "Sunday": 6}
        if date_string in week_days.keys():
            offset = (today.weekday() - week_days[date_string]) % 7
        elif date_string in ["Last " + x for x in week_days.keys()]:
            offset = 7 + (today.weekday() - week_days[date_string.strip('Last ')]) % 7
        elif date_string == "Today":
            offset = 0
        elif date_string == "Yesterday":
            offset = 1
        else:
            return(date_string)
            exit
        show_date = today - timedelta(days=offset)
        return(show_date.strftime('%a %d %b %Y')) 
        
        # This is an instance method    
    def cleaned_descriptive_content(self):
        show_title = self.content.find("div", class_ ="br-masthead__title").find("a").text
        show_details = self.content.find("div", class_ ="island")
        show_banner = self.content.find("h1", class_ = "no-margin").text
        show_description = self.content.find("div", class_ = "text--prose longest-synopsis").find("p").text    
        broadcast = self.content.find("div", class_="broadcast-event programme programme--grid highlight-box--grid")
        service_img = broadcast.find("div", class_="programme__img").find("img")['src']
        service_day = broadcast.find("span", class_ = "broadcast-event__date text-base timezone--date").text
        service_day = self.day_clean(service_day)
        service_time = broadcast.find("span", class_ = "timezone--time").text
        data = {"Show Title": show_title,
           "Show Banner": show_banner,
           "Show Description": show_description,
           "Service Image": service_img,
           "Service Day": service_day,
           "Service Time": service_time}
        return(data)

        # This is an instance method    
    def cleaned_playlist_content(self):
        music = self.content.find_all("div", class_="segment segment--music")
        cleaned_music = []
        for track in music:
            artist_image_segment = track.find("div", class_="segment__artist-image") 
            artist_image = artist_image_segment.find("img", class_="image lazyload")['data-src']
            track_segment = track.find("div", class_="segment__track")
            artist_name = track_segment.find("span", class_="artist").text
            track_name = track_segment.find("p", class_="no-margin").find("span").text
            record_label = track_segment.find("abbr", title="Record Label")
            if(record_label != None):
                record_label = record_label.text.strip().strip(".") 
            track_number = track_segment.find("abbr", title="Track Number")
            if(track_number != None):
                track_number = track_number.text.strip().strip(".") 
            row = {"Artist Image": artist_image,
                   "Artist Name": artist_name,
                   "Track Name": track_name,
                   "Record Label": record_label,
                   "Track Number": track_number}
            cleaned_music.append(row)
        
        track_listings = pd.DataFrame(cleaned_music)
        return(track_listings)

# %%
test = Playlist(URL = "https://www.bbc.co.uk/programmes/m001fb0m")
test.URL
# Out:
# 'https://www.bbc.co.uk/programmes/m001fb0m'

# %%
test.cleaned_descriptive_content()
# Out:
# {'Show Title': "Radio 1's Indie Show with Jack Saunders",
#  'Show Banner': 'Inhaler',
#  'Show Description': "Inhaler join Jack to play a game of How Well Do You Know Your Fans, plus Jack's got your Indie News headlines with a brand new gig correspondent.",
#  'Service Image': 'https://programmes.files.bbci.co.uk/programmes-frontend/images/logos/svg/bbc_radio_one/service-b5c93f6c5d.svg',
#  'Service Day': 'Sun 27 Nov 2022',
#  'Service Time': '21:00'}

# %%
test.cleaned_playlist_content()
# Out:
#                                          Artist Image             Artist Name  \
# 0   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...           Enter Shikari
# 1   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...             Black Honey
# 2   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                 Jamie T
# 3   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...              Low Hummer
# 4   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...               Metronomy
# 5   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                CHVRCHES
# 6   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                Gorillaz
# 7   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...          Lizzy McAlpine
# 8   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...               The Snuts
# 9   https://ichef.bbci.co.uk/images/ic/96x96/p01c9...           You Me at Six
# 10  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...              Yves Tumor
# 11  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...              Sam Fender
# 12  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...  Florence + the Machine
# 13  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                 Wet Leg
# 14  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...        Connie Constance
# 15  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                  FIDLAR
# 16  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                  Bandit
# 17  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...       As December Falls
# 18  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...              Pale Waves
# 19  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...            Tom A. Smith
# 20  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                 Inhaler
# 21  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...         Yeah Yeah Yeahs
# 22  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                    Feet
# 23  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                 THUMPER
# 24  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                   Civic
# 25  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...                Softcult
# 26  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...         Dolores Forever
# 27  https://ichef.bbci.co.uk/images/ic/96x96/p01c9...             The Killers
#
#                                            Track Name  \
# 0                                                Bull
# 1                                               Heavy
# 2                                   Between The Rocks
# 3                                         Panic Calls
# 4                                It's Good To Be Back
# 5                                 The Mother We Share
# 6                                          Baby Queen
# 7                                orange show speedway
# 8                                   Hallelujah Moment
# 9   Mixed Emotions (I Didn't Know How To Tell You ...
# 10                                    God Is A Circle
# 11                                        Spit Of You
# 12                                    Dream Girl Evil
# 13                                             Ur Mum
# 14                                           Hurt You
# 15                                  Sand on the Beach
# 16                                        Happy Pills
# 17                                             Mayday
# 18                                              Clean
# 19                                        Like You Do
# 20                            Love Will Get You There
# 21                                               Maps
# 22                                        Cant Get In
# 23                                     Summer Assault
# 24                                    End Of The Line
# 25                                              Drain
# 26          Conversations With Strangers [short edit]
# 27                               The Man [short edit]
#
#                 Record Label Track Number
# 0                       None         None
# 1            Foxfive Records         None
# 2                    Polydor         None
# 3                       None         None
# 4                       None         None
# 5             Virgin Records         None
# 6                       None         None
# 7    Harbour Artists & Music         None
# 8                 Parlophone         None
# 9        AWAL Recordings Ltd         None
# 10                      None         None
# 11                   Polydor         None
# 12                   Polydor         None
# 13  Domino Recording Company         None
# 14         Play It Again Sam         None
# 15                      None         None
# 16                      None         None
# 17                      None         None
# 18                 Dirty Hit            6
# 19                      None         None
# 20                   Polydor         None
# 21          Dress Up/Polydor         None
# 22                      None         None
# 23                      None         None
# 24                      None         None
# 25         Easy Life Records         None
# 26                      None         None
# 27                      None         None
