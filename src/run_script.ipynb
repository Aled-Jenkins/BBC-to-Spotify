# %%
# %run updating_data.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...
# Broadcast: 100%|██████████| 184/184 [01:20<00:00,  2.29it/s]

# %%
# %run spotipy_code.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Iteration  1  of  2385 :  : Faking Jazz Together
# Error with:   : Faking Jazz Together
# Iteration  2  of  2385 :  : Same Man (Nic Fanciulli Remix)
# Error with:   : Same Man
# Iteration  3  of  2385 : ...From The Benthic Zone : Edwin
# Error with:  From The Benthic Zone : Edwin
# Iteration  4  of  2385 : 128kps : D4y n N1t3 (Phasmid's Unnecessary Mix)
# Error with:  128kps : D4y n N1t3
# Iteration  5  of  2385 : 187 Lockdown : Gunman
# Error with:  187 Lockdown : Gunman
# Iteration  6  of  2385 : 24Hour Experience : Together
# Error with:  24Hour Experience : Together
# Iteration  7  of  2385 : 2DB : Mesmerised
# Error with:  2DB : Mesmerised
# Iteration  8  of  2385 : 2nd Natur(e) : Ngoma Yase Phesheya - 2nd Natur(e) Remix
# ...

# %%
# %run spotify_playlists.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/GitHub Repos/BBC-to-Spotify/src/spotify_playlists.ipynb in <module>
#       3 title = "Indie Show with Jack Saunders"
#       4 description = "Songs from the Indie Show with Jack Saunders in 2022"
# ----> 5 edit_playlist_tracks(playlists[playlists['name'] == title]['id'][0], new_tracks)
#
# ~/GitHub Repos/BBC-to-Spotify/src/spotify_playlists.ipynb in edit_playlist_tracks(playlist_id, new_tracks, order)
#       1 def edit_playlist_tracks(playlist_id, new_tracks, order = True):
#       2
# ----> 3     get_playlist(playlist_id = playlist_id, with_tracks = True)
#       4
# ...
