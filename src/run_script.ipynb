# %%
# %run updating_data.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...
# Broadcast: 100%|██████████| 324/324 [02:13<00:00,  2.43it/s]

# %%
# %run spotipy_code.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Iteration  1  of  3219 : ...From The Benthic Zone : Edwin
# Error with:  ...From The Benthic Zone : Edwin
# Iteration  2  of  3219 : 11:11 : Against The Wall
# Iteration  3  of  3219 : 128kps : D4y n N1t3 (Phasmid's Unnecessary Mix)
# Error with:  128kps : D4y n N1t3
# Iteration  4  of  3219 : 187 Lockdown : Gunman
# Error with:  187 Lockdown : Gunman
# Iteration  5  of  3219 : 1991 : Horizon
# Iteration  6  of  3219 : 24Hour Experience : Together
# Error with:  24Hour Experience : Together
# Iteration  7  of  3219 : 2DB : Mesmerised
# Error with:  2DB : Mesmerised
# Iteration  8  of  3219 : 2nd Natur(e) : Ngoma Yase Phesheya - 2nd Natur(e) Remix
# Error with:  2nd Natur : Ngoma Yase Phesheya - 2nd Natur Remix
# ...

# %%
# %run spotify_playlists.ipynb
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# ...
#  37%|███▋      | 1901/5175 [10:20<17:47,  3.07it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/GitHub Repos/BBC-to-Spotify/src/spotify_playlists.ipynb in <module>
#       3 title = "Steve Lamacq"
#       4 description = "Songs from Steve Lamacq's Show in 2022"
# ----> 5 edit_playlist_tracks(playlists[playlists['name'] == title]['id'][0], new_tracks)
#
# ~/GitHub Repos/BBC-to-Spotify/src/spotify_playlists.ipynb in edit_playlist_tracks(playlist_id, new_tracks, order)
#      40             pos = int(new_tracks_df.loc[i, 'Position Number'])
#      41             if new_pos != pos:
# ...
