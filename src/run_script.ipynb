# %%
# %run updating_data.ipynb
# Out:
# ...
# 100%|██████████| 37/37 [00:08<00:00,  4.59it/s]

# %%
# %run spotipy_code.ipynb
# Out:
# Iteration  1  of  1683 :  : Faking Jazz Together
# Error with:   : Faking Jazz Together
# Iteration  2  of  1683 :  : Same Man (Nic Fanciulli Remix)
# Error with:   : Same Man
# Iteration  3  of  1683 : !Action Pact! : Yet Another Dole Queue Song
# Iteration  4  of  1683 : +HIRS+ : Y'all Are Precious.
# Error with:  +HIRS+ : Yall Are Precious.
# Iteration  5  of  1683 : ...From The Benthic Zone : Edwin
# Error with:  ...From The Benthic Zone : Edwin
# Iteration  6  of  1683 : 128kps : D4y n N1t3 (Phasmid's Unnecessary Mix)
# Error with:  128kps : D4y n N1t3
# Iteration  7  of  1683 : 24Hour Experience : Together
# Error with:  24Hour Experience : Together
# Iteration  8  of  1683 : 2DB : Mesmerised
# Error with:  2DB : Mesmerised
# Iteration  9  of  1683 : 801 : Tomorrow Never Knows
# Error with:  801 : Tomorrow Never Knows
# Iteration  10  of  1683 : 93FEETOFSMOKE : feel something at all
# Iteration  11  of  1683 : 9TRANE : Made It Thru (9TRANE'S Back to '91 Mix)
# ...

# %%
# %run spotify_playlists.ipynb
